# %% [markdown]
# ___
# # Ciência dos Dados - PROJETO 1

# %% [markdown]
# ## COLOQUE AQUI SEU NOME
# ___

# %% [markdown]
# ## TÍTULO DO SEU PROJETO

# %% [markdown]
# ___
# ## Introdução
#
# Descreva aqui o que pretende analisar!
#
# Capriche no português!!
# Se quiser pode utilizar pesquisas semelhantes publicadas em sites confiáveis!!

# %% [markdown]
# ___
# ## Análise e Resultados

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
print('Esperamos trabalhar no diretório')
print(os.getcwd())
# Out:
# Esperamos trabalhar no diretório
# /Users/lucasvaz/Desktop

# %%
#Se usar o arquivo descompactado
#pd.read_csv('DOM2015.csv',sep=',')
dados=pd.read_csv("DOM2015.csv")
dados.UF = dados.UF.astype('category')
#Se usar o arquivo compactado como está no dropbox púbico
#pd.read_csv('DOM2015csv.zip', compression='zip', header=0, sep=',', quotechar='"'

# %%
netcell=dados.V02324
netcomp=dados.V02323
nettablet=dados.V02325
nettv=dados.V02326
netoutro=dados.V02327
estado=dados.UF

#novo data frame

DF = pd.DataFrame()

#Dando nomes

DF["Estado"]=estado
DF["netCelular"]=netcell
DF["netMicroComputador"]=netcomp
DF["netTablet"]=nettablet
DF["netTv"]=nettv
DF["netOutros"]=netoutro

#transformando variaveis

DF.estado=DF.Estado.astype("category")
DF.netCelular=DF.netCelular.astype("category")
DF.netMicroComputador=DF.netMicroComputador.astype("category")
DF.netTablet=DF.netTablet.astype("category")
DF.netTv=DF.netTv.astype("category")
DF.netOutros=DF.netOutros.astype("category")


#Traduzindo Numeros
DF.netCelular.cat.categories = (["sim", "não"])
DF.netMicroComputador.cat.categories = (["sim", "não"])
DF.netTablet.cat.categories = (["sim", "não"])
DF.netTv.cat.categories = (["sim", "não"])
DF.netOutros.cat.categories = (["sim", "não"])
DF[DF.Estado==35]
# Out:
#        Estado netCelular netMicroComputador netTablet netTv netOutros
# 93131      35        NaN                NaN       NaN   NaN       NaN
# 93132      35        sim                sim       sim   não       não
# 93133      35        sim                sim       sim   não       não
# 93134      35        NaN                NaN       NaN   NaN       NaN
# 93135      35        sim                sim       não   não       não
# 93136      35        NaN                NaN       NaN   NaN       NaN
# 93137      35        NaN                NaN       NaN   NaN       NaN
# 93138      35        NaN                NaN       NaN   NaN       NaN
# 93139      35        NaN                NaN       NaN   NaN       NaN
# 93140      35        sim                sim       não   não       não
# 93141      35        NaN                NaN       NaN   NaN       NaN
# 93142      35        NaN                NaN       NaN   NaN       NaN
# 93143      35        sim                sim       não   não       não
# 93144      35        NaN                NaN       NaN   NaN       NaN
# 93145      35        NaN                NaN       NaN   NaN       NaN
# 93146      35        NaN                NaN       NaN   NaN       NaN
# 93147      35        sim                sim       não   não       não
# 93148      35        sim                sim       não   não       não
# 93149      35        sim                sim       não   não       não
# 93150      35        não                sim       não   não       não
# 93151      35        NaN                NaN       NaN   NaN       NaN
# 93152      35        NaN                NaN       NaN   NaN       NaN
# 93153      35        NaN                NaN       NaN   NaN       NaN
# 93154      35        NaN                NaN       NaN   NaN       NaN
# 93155      35        NaN                NaN       NaN   NaN       NaN
# 93156      35        sim                não       não   não       não
# 93157      35        sim                sim       não   não       não
# 93158      35        NaN                NaN       NaN   NaN       NaN
# 93159      35        NaN                NaN       NaN   NaN       NaN
# 93160      35        sim                sim       sim   não       não
# ...       ...        ...                ...       ...   ...       ...
# 110392     35        NaN                NaN       NaN   NaN       NaN
# 110393     35        sim                sim       sim   não       sim
# 110394     35        NaN                NaN       NaN   NaN       NaN
# 110395     35        NaN                NaN       NaN   NaN       NaN
# 110396     35        NaN                NaN       NaN   NaN       NaN
# 110397     35        NaN                NaN       NaN   NaN       NaN
# 110398     35        sim                sim       não   não       não
# 110399     35        NaN                NaN       NaN   NaN       NaN
# 110400     35        sim                sim       sim   sim       não
# 110401     35        sim                sim       não   não       não
# 110402     35        NaN                NaN       NaN   NaN       NaN
# 110403     35        sim                sim       sim   não       não
# 110404     35        não                sim       sim   não       não
# 110405     35        não                sim       não   não       não
# 110406     35        NaN                NaN       NaN   NaN       NaN
# 110407     35        NaN                NaN       NaN   NaN       NaN
# 110408     35        sim                sim       sim   não       não
# 110409     35        sim                sim       não   não       não
# 110410     35        sim                sim       não   não       não
# 110411     35        sim                sim       não   não       não
# 110412     35        sim                sim       não   não       não
# 110413     35        NaN                NaN       NaN   NaN       NaN
# 110414     35        sim                sim       sim   não       não
# 110415     35        sim                não       não   não       não
# 110416     35        sim                sim       não   não       não
# 110417     35        NaN                NaN       NaN   NaN       NaN
# 110418     35        sim                sim       sim   não       não
# 110419     35        NaN                NaN       NaN   NaN       NaN
# 110420     35        sim                sim       não   não       não
# 110421     35        não                sim       sim   não       não
#
# [17291 rows x 6 columns]

# %% [markdown]
# ___
# ## Conclusão

# %% [markdown]
# Descreva aqui suas conclusões!

# %%
ut1 = (DF.netTablet.value_counts(sort=False, normalize=False)).round(decimals=1)
print(ut1,'\n')
ut2 = (DF.netCelular.value_counts(sort=False, normalize=False)).round(decimals=1)
print(ut2,'\n')
ut3 = (DF.netMicroComputador.value_counts(sort=False, normalize=False)).round(decimals=1)
print(ut3,'\n')
ut4 = (DF.netTv.value_counts(sort=False, normalize=False)).round(decimals=1)
print(ut4,'\n')
ut5 = (DF.netOutros.value_counts(sort=False, normalize=False)).round(decimals=1)
print(ut5,'\n')
# Out:
# sim    13884
# não    53950
# Name: netTablet, dtype: int64
#
# sim    62996
# não     4838
# Name: netCelular, dtype: int64
#
# sim    45945
# não    21889
# Name: netMicroComputador, dtype: int64
#
# sim     4908
# não    62926
# Name: netTv, dtype: int64
#
# sim      641
# não    67193
# Name: netOutros, dtype: int64
